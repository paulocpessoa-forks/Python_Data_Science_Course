# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
x = np.linspace(0,5,11)
y = x **2

# %%
plt.plot(x, y, 'r') # 'r' is the color red
plt.xlabel('X Axis Title Here')
plt.ylabel('Y Axis Title Here')
plt.title('String Title Here')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-99a445d3758e> in <module>()
#       1 plt.plot(x, y, 'r') # 'r' is the color red
# ----> 2 plt.xlabel('X Axis Title Here')
#       3 plt.ylabel('Y Axis Title Here')
#       4 plt.title('String Title Here')
#       5 plt.show()
#
# TypeError: 'str' object is not callable

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')
plt.subplot(1,2,2)
plt.plot(x,y,'b')

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)
axes.set_xlabel('xlabel')
axes.set_ylabel('ylabel')

# %%
fig = plt.figure()
#axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
#axes2 = fig.add_axes([0.2,0.5,0.4,0.3])
axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])
axes1.plot(x,y)
axes2.plot(y,x)

# %%
fig,axes = plt.subplots(nrows = 1, ncols=2)
#axes.plot(x,y)
#plt.tight_layout()

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000165DCFC7EB8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000165DE44A390>],
#       dtype=object)

# %%
for current_x in axes:
    current_x.plot(x,y)

# %%
fig,axes = plt.subplots()

# %%
axes.plot(x,y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-87-ecbc872ddef0> in <module>()
# ----> 1 axes.plot(x,y)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)

axes[0].plot(x,y)
axes[0]

axes[1].plot(y,x)

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000165DD145A58>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000165DE59D128>],
#       dtype=object)

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)

for cur_ax in axes:
    cur_ax.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)

axes[0].plot(x,y)
axes[0].set_title('Graph 0')

axes[1].plot(y,x)
axes[1].set_title('Graph 1')
# Out:
# Text(0.5,1,'Graph 1')

# %%
fig.savefig('my_picture.png',dpi=400)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label='x squared')
ax.plot(x,x**3,label='x cubed')

ax.legend(loc=(0.1,0.1))
